# %% [markdown]
# # Retrieval Sanity Checks
#
# This notebook compares lexical and dense runs using standardized output files.

# %%
from pathlib import Path
import pandas as pd
import os,sys
NOTEBOOK_DIR = Path.cwd()
PROJECT_ROOT = NOTEBOOK_DIR.parent.resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
from src.utils.metrics_sanity import topk_overlap, score_distribution_summary

base = PROJECT_ROOT /"outputs"/"dev"
tfidf = pd.read_csv(base / "tfidf" / "tfidf_top10.csv")
bm25 = pd.read_csv(base / "bm25" / "bm25_top10.csv")

print("TF-IDF score summary:", score_distribution_summary(tfidf))
print("BM25 score summary:", score_distribution_summary(bm25))
display(topk_overlap(tfidf, bm25, top_k=10))
# Out:
# TF-IDF score summary: {'min': 0.066717519551755, 'max': 0.40063540542014, 'mean': 0.13995637673605804, 'median': 0.12874728831683468, 'std': 0.05457590361216952}
# BM25 score summary: {'min': 3.1621133410450724, 'max': 14.500597043683978, 'mean': 6.578598174658594, 'median': 6.228523554858709, 'std': 2.238559027550057}
#    query_id  top_k  overlap_count   jaccard
# 0        Q1     10              3  0.176471
# 1       Q10     10              4  0.250000
# 2       Q11     10              9  0.818182
# 3       Q12     10              2  0.111111
# 4       Q13     10              5  0.333333
# 5       Q14     10              8  0.666667
# 6       Q15     10              6  0.428571
# 7       Q16     10              4  0.250000
# 8       Q17     10              6  0.428571
# 9       Q18     10              6  0.428571
# 10      Q19     10              3  0.176471
# 11       Q2     10              6  0.428571
# 12      Q20     10              8  0.666667
# ...
